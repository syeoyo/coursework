# %% [markdown]
# ### Chp2: Asset Selling

# %%
'''
[ERROR] AssetSellingDriverScript: Line 21 -> Line 22
[ERROR] AssetSellingDriverScript_Q3: Line 24 -> Line 25
'''

import os
original_dir = os.getcwd()
os.chdir('./AssetSelling')
# %run AssetSellingDriverScript.py
# %run AssetSellingDriverScript_Q3.py
os.chdir(original_dir)

# %% [markdown]
# ### Chp3: Adaptive Market Planning

# %%
'''
[ERROR] AdaptiveMarketPlanningDriverScript: Line 27~32 -> Line 34~39
'''

import os
original_dir = os.getcwd()
os.chdir('./AdaptiveMarketPlanning')
# %run AdaptiveMarketPlanningDriverScript.py
os.chdir(original_dir)

# %%
'''
[ERROR] ParametricModelDriverScript: Line 27~33 -> Line 35~41
'''

import os
original_dir = os.getcwd()
os.chdir('./AdaptiveMarketPlanning')
# %run ParametricModelDriverScript.py
os.chdir(original_dir)

# %% [markdown]
# ### Chp4: Medical Decision Diabetes

# %%
'''
[ERROR] MedicalDecisionDiabetesDriverScript: Line 51~52 -> Line 53~54
'''

import os
original_dir = os.getcwd()
os.chdir('./MedicalDecisionDiabetes')
# %run MedicalDecisionDiabetesDriverScript.py
os.chdir(original_dir)

# %% [markdown]
# ### Chp5: Stochastic Shortest Path - Static

# %%
import os
original_dir = os.getcwd()
os.chdir('./StochasticShortestPath_Static')
# %run DriverScriptAdaptive.py
os.chdir(original_dir)

# %% [markdown]
# ### Chp6: Stochastic Shortest Path - Dynamic

# %%
import os
original_dir = os.getcwd()
os.chdir('./StochasticShortestPath_Dynamic')
# %run Driver.py
os.chdir(original_dir)

# %% [markdown]
# ### Chp8: Energy Storage 1

# %%
'''
[ERROR] EnergyStorageDriverScript: Line 45~46 -> Line 47~48 / Line 64~65 -> Line 66~67
'''

import os
original_dir = os.getcwd()
os.chdir('./EnergyStorage_I')
# %run EnergyStorageDriverScript.py
os.chdir(original_dir)

# %% [markdown]
# ### Chp10: Two Newsvendor

# %%
'''
[ERROR] TwoNewsvendorDriverScript: Line 193 -> Line 194
[ENV] terminal: python TwoNewsvendorDriverScript.py
'''

import os
import subprocess

os.chdir('./TwoNewsvendor')
result = subprocess.run(['python', 'TwoNewsvendorDriverScript.py'], capture_output=True, text=True)

print("출력:") ; print(result.stdout)
if result.stderr: print("에러:") ; print(result.stderr)

os.chdir('..')

# %% [markdown]
# ### Chp13: Blood Management

# %%
'''
[ERROR] BloodManagementDriverScript: Line 468 -> Line 469 / Line 550 -> Line 551
'''

import os
original_dir = os.getcwd()
os.chdir('./BloodManagement')
# %run BloodManagementDriverScript.py
os.chdir(original_dir)

# %% [markdown]
# ### Chp14: Clinical Trials

# %%
'''
[ERROR] ClinicalTrialsDriverScript: Line 27~48 -> Line 50~72
말고도 문제 많은듯
'''

import os
original_dir = os.getcwd()
os.chdir('./ClinicalTrials')
# %run ClinicalTrialsDriverScript.py
# %run ClinicalTrialsDriverScriptSolutionQ4.py
# %run ClinicalTrialsDriverScriptSolutionQ5.py
# %run ClinicalTrialsDriverScriptSolutionQ6.py
os.chdir(original_dir)
